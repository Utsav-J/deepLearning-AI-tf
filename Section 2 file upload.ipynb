# %%
import pandas as pd
import tensorflow as tf

# %%
# !wget https://archive.ics.uci.edu/static/public/9/auto+mpg.zip
# Out:
# --2023-12-05 13:04:45--  https://archive.ics.uci.edu/static/public/9/auto+mpg.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘auto+mpg.zip’
#
# auto+mpg.zip            [ <=>                ]  14.52K  --.-KB/s    in 0.04s
#
# 2023-12-05 13:04:45 (384 KB/s) - ‘auto+mpg.zip’ saved [14873]

# %%
from zipfile import ZipFile
with ZipFile("auto+mpg.zip",'r') as zip_ref:
  zip_ref.extractall("/content")

# %%
with tf.io.gfile.GFile('auto-mpg.data','rb') as downloaded_data:
  data = downloaded_data.read()

# %%
df = pd.read_csv("auto-mpg.data",header = None,delim_whitespace = True)

# %%
df.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
