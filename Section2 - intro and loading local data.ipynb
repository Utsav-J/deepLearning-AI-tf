# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10*np.pi,1000)  #generates 1000 evenlyspaced, values betweem 0 and 10 pi
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.14.0

# %%
# !ls
# Out:
# sample_data

# %%
# !ls sample_data
# Out:
# anscombe.json		     california_housing_train.csv  mnist_train_small.csv
# california_housing_test.csv  mnist_test.csv		   README.md

# %% [markdown]
# ##GET YOUR OWN DATA

# %%
# !wget https://archive.ics.uci.edu/static/public/5/arrhythmia.zip
# Out:
# --2023-12-05 12:03:52--  https://archive.ics.uci.edu/static/public/5/arrhythmia.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘arrhythmia.zip’
#
# arrhythmia.zip          [ <=>                ]  96.52K  --.-KB/s    in 0.08s
#
# 2023-12-05 12:03:52 (1.18 MB/s) - ‘arrhythmia.zip’ saved [98839]

# %%
# !ls
# Out:
# arrhythmia.zip	sample_data

# %%
# !head arrhythmia.zip
# Out:
# ��Varrhythmia.data��Yv+��6����^�@�����f4]n����l�#Rd��@t_���}��Oq�
# ��|?�[)��]��;�Й��,�@�����2Q��T����6`c@���c(��e�<]A���ğ�O��S�#�Ϊ��,�#�~즋@�������A��0}
# ��}�N��h�[R�����`�hJ�>v�u���"=C�bI>sF������u-r�S�٦P-��*�nn=��,��.���+��C�J�V���m=s��m�*�w��(����<�/��d�v�|�xn���8)Bz�A�^��7.S���Z�M��O	r��}�$���Y��	�^��-�|��n�����y�0�N�k�t����H�d%�i���I���b�̮��Rc�b+�m[���I|�n9���M�~��U;��Г#=a��%�=�Fy2R��d�D&�%���R��3ej�n�=W��n	����Z8N8����@�9V�9M�#e�7qB��߹J�E�7��v/\~������M����;��k�J��_ߌڂr! ��|v� %r�$��Q���"������ƧdK�e9�Q�A���Or�.�,�O�K��=�����R�"U�����v�ߥ�C�e���~K���6�����	{�<Ly�e�3N�p�v����|����>_;}�q�t�Z�&����M��#ږ.�w-�f����7�����R�f��,���^�D^
# �`��e�d�p�߅̙����ۮ����Rk{=��D�ɧ�'i�C�Y����J����T��o�vZ�N}t�,�`\�IՎ��;�x�9�$8h�/��	0�@����t��L���#��?�R��mJ�C񗊐f#��/'�v�_�|N��k�=�4Ď�w��P�en�?t�6��5�
# 3Y�f�^Z!i����[C����AY�N&�O���a����V��V�K,���n;,�U|�����-����ÊBd>���%O�-��($"���)���$�\/�9G��ry�
# ...

# %%
from zipfile import ZipFile
with ZipFile("arrhythmia.zip",'r') as zip_ref:
  zip_ref.extractall("content/dataset")

# %%
# !ls content
# Out:
# dataset

# %%
data_location = "content/dataset/arrhythmia.data"

# %%
import pandas as pd
df = pd.read_csv(data_location,header = None)

# %%
first_five = df[[0,1,2,3,4,5]]
first_five.columns = ['age','sex','height','weight','QRS Duration', "PR Interval"]

# %%
first_five
# Out:
#      age  sex  height  weight  QRS Duration  PR Interval
# 0     75    0     190      80            91          193
# 1     56    1     165      64            81          174
# 2     54    0     172      95           138          163
# 3     55    0     175      94           100          202
# 4     75    0     190      80            88          181
# ..   ...  ...     ...     ...           ...          ...
# 447   53    1     160      70            80          199
# 448   37    0     190      85           100          137
# 449   36    0     166      68           108          176
# 450   32    1     155      55            93          106
# 451   78    1     160      70            79          127
#
# [452 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
first_five.hist();

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(first_five);
